# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2018,1,1)

# %%
tesla = web.DataReader("TSLA",'yahoo',start,end)
ford = web.DataReader("F",'yahoo',start,end)
gm = web.DataReader("GM",'yahoo',start,end)

# %%
tesla.to_csv('Tesla_Stock.csv')
ford.to_csv('Ford_Stock.csv')
gm.to_csv('GM_Stock.csv')

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889

# %%
tesla['Open'].plot(label = 'TESLA Open price', figsize=(16,7.5))
tesla['Close'].plot(label = 'TESLA Close price')
tesla['High'].plot()
tesla['Low'].plot()
plt.legend()
plt.title('Tesla Stock Price')
plt.ylabel('Stock Price')
plt.show()

# %%
tesla['Open'].plot(label = 'Tesla', figsize=(16,7.5))
ford['Open'].plot(label = 'Ford')
gm['Open'].plot(label = 'GM')
plt.ylabel('Stock Price')
plt.title('Stock Prices of Tesla, Ford and GM')
plt.legend()

# %%
tesla['Volume'].plot(label='Tesla', figsize=(15,7))
ford['Volume'].plot(label='Ford')
gm['Volume'].plot(label='GM')
plt.ylabel('Volume Traded')
plt.legend()

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#             High    Low   Open  Close       Volume  Adj Close
# Date
# 2013-12-18  16.0  15.17  15.99  15.65  220363000.0  11.093974

# %%
ford.iloc[490:580]['Open'].plot(figsize=(17,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916  6.386011e+08

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889
#
#             Total Traded
# Date
# 2012-01-03  1.941627e+08
# 2012-01-04  1.653835e+08
# 2012-01-05  3.772807e+08
# 2012-01-06  4.059000e+08
# 2012-01-09  2.803604e+08

# %%
tesla['Total Traded'].plot(label='Tesla',figsize=(15,7))
ford['Total Traded'].plot(label='Ford')
gm['Total Traded'].plot(label='GM')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 538

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#              High        Low  Open      Close     Volume  Adj Close  \
# Date
# 2014-02-25  51.84  45.689999  46.0  49.599998  163408500  49.599998
#
#             Total Traded
# Date
# 2014-02-25  7.516791e+09

# %%
ford['Total Traded'].argmax()
# Out:
# 493

# %%
ford.iloc[[ford['Total Traded'].argmax()]]
# Out:
#             High    Low   Open  Close       Volume  Adj Close  Total Traded
# Date
# 2013-12-18  16.0  15.17  15.99  15.65  220363000.0  11.093974  3.523604e+09

# %%
gm['Total Traded'].argmax()
# Out:
# 511

# %%
gm.iloc[[gm['Total Traded'].argmax()]]
# Out:
#              High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2014-01-15  39.77  38.959999  39.630001  39.380001  89207600.0  30.436552
#
#             Total Traded
# Date
# 2014-01-15  3.535297e+09

# %%
gm['Open'].iloc[440:500].plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gm['Open'].plot(label='No moving Avg',figsize=(15,7))
gm['MA50'] = gm['Open'].rolling(50).mean()
gm['MA50'].plot(label='MA50')
gm['MA150'] = gm['Open'].rolling(150).mean()
gm['MA150'].plot(label='MA150')
gm['MA250'] = gm['Open'].rolling(250).mean()
gm['MA250'].plot(label='MA250')
plt.legend()

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_comp = pd.concat([tesla['Open'],ford['Open'],gm['Open']], axis =1)
car_comp.columns = ['Tesla Open', 'Ford Open', 'GM Open']

# %%
scatter_matrix(car_comp, figsize=(10,8),hist_kwds={'bins':50})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>]], dtype=object)

# %%
import mplfinance as mpf
import pandas as pd

# %%
file = 'Ford_Stock.csv'
data = pd.read_csv(file)

# %%
data
# Out:
#             Date   High    Low   Open  Close      Volume  Adj Close
# 0     2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740
# 1     2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981
# 2     2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563
# 3     2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905
# 4     2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916
# ...          ...    ...    ...    ...    ...         ...        ...
# 1504  2017-12-22  12.66  12.56  12.66  12.58  17876200.0  10.821597
# 1505  2017-12-26  12.65  12.55  12.57  12.60  11664600.0  10.838800
# 1506  2017-12-27  12.58  12.45  12.57  12.50  17005600.0  10.752779
# 1507  2017-12-28  12.58  12.47  12.48  12.58  14793500.0  10.821597
# 1508  2017-12-29  12.61  12.49  12.58  12.49  18362500.0  10.744176
#
# [1509 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1509 non-null   object
#  1   High       1509 non-null   float64
#  2   Low        1509 non-null   float64
#  3   Open       1509 non-null   float64
#  4   Close      1509 non-null   float64
#  5   Volume     1509 non-null   float64
#  6   Adj Close  1509 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 82.6+ KB

# %%
data.columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
data.Date = pd.to_datetime(data.Date)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1509 non-null   datetime64[ns]
#  1   High       1509 non-null   float64
#  2   Low        1509 non-null   float64
#  3   Open       1509 non-null   float64
#  4   Close      1509 non-null   float64
#  5   Volume     1509 non-null   float64
#  6   Adj Close  1509 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 82.6 KB

# %%
data = data.set_index('Date')

# %%
mpf.plot(data)
# Out:
# c:\users\sanket agarwal\appdata\local\programs\python\python39\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(data['2017-07'], type= 'candle', volume = True)
# Out:
# C:\Users\SANKET~1\AppData\Local\Temp/ipykernel_6560/2939299040.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   mpf.plot(data['2017-07'], type= 'candle', volume = True)

# %%
tesla ['return'] = (tesla['Close'] / tesla['Close'].shift(1))-1

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07
#
#               return
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.013177
# 2012-01-05 -0.021292
# 2012-01-06 -0.007743
# 2012-01-09  0.012635

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916  6.386011e+08

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889
#
#             Total Traded  MA50  MA150  MA250
# Date
# 2012-01-03  1.941627e+08   NaN    NaN    NaN
# 2012-01-04  1.653835e+08   NaN    NaN    NaN
# 2012-01-05  3.772807e+08   NaN    NaN    NaN
# 2012-01-06  4.059000e+08   NaN    NaN    NaN
# 2012-01-09  2.803604e+08   NaN    NaN    NaN

# %%
ford['return'] = (ford['Close'] / ford['Close'].shift(1))-1

# %%
gm ['return'] = (gm['Close'] / gm['Close'].shift(1))-1

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889
#
#             Total Traded  MA50  MA150  MA250    return
# Date
# 2012-01-03  1.941627e+08   NaN    NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN    NaN -0.003490

# %%
ford['return'].hist(bins=50,figsize=(8,7))
# Out:
# <AxesSubplot:>

# %%
tesla['return'].hist(bins=50,figsize=(8,7))
# Out:
# <AxesSubplot:>

# %%
gm['return'].hist(bins=50,figsize=(8,7))
# Out:
# <AxesSubplot:>

# %%
tesla['return'].hist(bins=100, label='TESLA',alpha=0.5, figsize=(11,7))
ford['return'].hist(bins=100, label='FORD',alpha=0.5)
gm['return'].hist(bins=100, label='GM',alpha=0.5)
plt.legend()

# %%
tesla['return'].plot(kind='kde', label='TESLA',figsize=(13,6))
ford['return'].plot(kind='kde', label='FORD')
gm['return'].plot(kind='kde', label='GM')
plt.legend()

# %%
box_df= pd.concat([tesla['return'],ford['return'],gm['return']], axis=1)
box_df.columns=['Tesla return','Ford return', 'GM return']
box_df.plot(kind ='box',figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df,figsize=(9,9),hist_kwds={'bins':50},alpha=0.25)
# Out:
# array([[<AxesSubplot:xlabel='Tesla return', ylabel='Tesla return'>,
#         <AxesSubplot:xlabel='Ford return', ylabel='Tesla return'>,
#         <AxesSubplot:xlabel='GM return', ylabel='Tesla return'>],
#        [<AxesSubplot:xlabel='Tesla return', ylabel='Ford return'>,
#         <AxesSubplot:xlabel='Ford return', ylabel='Ford return'>,
#         <AxesSubplot:xlabel='GM return', ylabel='Ford return'>],
#        [<AxesSubplot:xlabel='Tesla return', ylabel='GM return'>,
#         <AxesSubplot:xlabel='Ford return', ylabel='GM return'>,
#         <AxesSubplot:xlabel='GM return', ylabel='GM return'>]],
#       dtype=object)

# %%
tesla['Cummulative return'] = (1 + tesla['return']).cumprod()
ford['Cummulative return'] = (1 + ford['return']).cumprod()
gm['Cummulative return'] = (1 + gm['return']).cumprod()
ford.head()
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889
#
#             Total Traded  MA50  MA150  MA250    return  Cummulative return
# Date
# 2012-01-03  1.941627e+08   NaN    NaN    NaN       NaN                 NaN
# 2012-01-04  1.653835e+08   NaN    NaN    NaN  0.004751            1.004751
# 2012-01-05  3.772807e+08   NaN    NaN    NaN  0.048227            1.053207
# 2012-01-06  4.059000e+08   NaN    NaN    NaN  0.033829            1.088836
# 2012-01-09  2.803604e+08   NaN    NaN    NaN -0.003490            1.085036

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07
#
#               return  Cummulative return
# Date
# 2012-01-03       NaN                 NaN
# 2012-01-04 -0.013177            0.986823
# 2012-01-05 -0.021292            0.965812
# 2012-01-06 -0.007743            0.958333
# 2012-01-09  0.012635            0.970442

# %%
tesla['Cummulative return'].plot(label='Tesla',figsize=(10,8))
ford['Cummulative return'].plot(label='Ford',figsize=(10,8))
gm['Cummulative return'].plot(label='GM',figsize=(10,8))
plt.title('Cummulative Return vs Time')
plt.legend()
